# %%
from pathlib import Path
import pandas as pd
import numpy as np
import os
base_dir = Path(os.getcwd()).parents[2]
file_path = base_dir /'data' / 'aks01_pod_metrics.json'
# Load the JSON file into a DataFrame
print(f"Loading data from {file_path}")
df = pd.read_json(file_path)
# Out:
# Loading data from c:\Brijesh\Projects\Datascience\MLearn\KubeTuner\kubetune1.0\data\aks01_pod_metrics.json

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Correlation heatmap
features = [
        'cpuRequest', 'cpuLimit', 'cpuUsage',
        'memRequest', 'memLimit', 'memUsage',
    ]
plt.figure(figsize=(16, 10))
correlation = df[features].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap-On Raw Data')
plt.show()

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import os
base_dir = Path(os.getcwd()).parents[0]
file_path = base_dir /'timeseriesxgboost'/ 'output' / 'aks01_pod_metrics_processed.json'
# Load the JSON file into a DataFrame
print(f"Loading data from {file_path}")
df = pd.read_json(file_path,  lines=True)
# Out:
# Loading data from c:\Brijesh\Projects\Datascience\MLearn\KubeTuner\kubetune1.0\src\models\timeseriesxgboost\output\aks01_pod_metrics_processed.json

# %%
# Check the shape of the dataset
print(f"Dataset Shape: {df.shape}")
# Check the data types of each column
print(df.info())
# Check for missing values
print(df.isnull().sum())
# Get basic statistics for numerical columns
print(df.describe())
# Out:
# Dataset Shape: (4980, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4980 entries, 0 to 4979
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              4980 non-null   datetime64[ns]
#  1   controllerName         4980 non-null   object
#  2   cpuRequest             4980 non-null   float64
#  3   cpuLimit               4980 non-null   float64
#  4   cpuUsage               4980 non-null   float64
#  5   memRequest             4980 non-null   float64
#  6   memLimit               4980 non-null   float64
#  7   memUsage               4980 non-null   float64
#  8   avg_cpu_5min           4980 non-null   float64
#  9   avg_mem_5min           4980 non-null   float64
#  10  max_cpu                4980 non-null   float64
#  11  max_mem                4980 non-null   float64
#  12  hour                   4980 non-null   int64
#  13  dayofweek              4980 non-null   int64
#  14  is_weekend             4980 non-null   bool
#  15  cpu_utilization_ratio  4980 non-null   float64
#  16  mem_utilization_ratio  4980 non-null   float64
#  17  cat_deployment         4980 non-null   int64
#  18  cat_namespace          4980 non-null   int64
#  19  cat_controllerName     4980 non-null   int64
#  20  cat_controllerKind     4980 non-null   int64
# dtypes: bool(1), datetime64[ns](1), float64(12), int64(6), object(1)
# memory usage: 783.1+ KB
# None
# timestamp                0
# controllerName           0
# cpuRequest               0
# cpuLimit                 0
# cpuUsage                 0
# memRequest               0
# memLimit                 0
# memUsage                 0
# avg_cpu_5min             0
# avg_mem_5min             0
# max_cpu                  0
# max_mem                  0
# hour                     0
# dayofweek                0
# is_weekend               0
# cpu_utilization_ratio    0
# mem_utilization_ratio    0
# cat_deployment           0
# cat_namespace            0
# cat_controllerName       0
# cat_controllerKind       0
# dtype: int64
#                            timestamp   cpuRequest     cpuLimit     cpuUsage  \
# count                           4980  4980.000000  4980.000000  4980.000000
# mean   2025-06-13 00:06:19.483690496     0.192944     0.501467     0.028469
# min       2025-06-12 10:58:52.764000     0.000000     0.000000     0.000000
# 25%    2025-06-12 11:24:57.767000064     0.010000     0.100000     0.000300
# 50%    2025-06-13 08:20:30.947000064     0.050000     0.200000     0.003550
# 75%    2025-06-13 13:32:43.862000128     0.100000     0.500000     0.016800
# max       2025-06-13 18:44:39.276000     4.096000     8.000000     1.007400
# std                              NaN     0.550616     0.981325     0.103547
#
#          memRequest      memLimit      memUsage  avg_cpu_5min  avg_mem_5min  \
# count   4980.000000   4980.000000   4980.000000   4980.000000   4980.000000
# mean     572.862731   1323.137462    241.668325      0.028473    241.669263
# min        0.000000      0.000000      0.000000      0.000000      1.030000
# 25%       47.680000    128.000000     18.675000      0.004200     55.160000
# 50%      128.000000    256.000000     64.140000      0.011500    101.425000
# 75%      400.000000   1024.000000    147.040000      0.023400    173.905000
# max    16384.000000  32768.000000  32766.530000      1.001400   8451.710000
# std     1933.900232   3809.685198   1187.858738      0.065740    596.447578
#
#            max_cpu       max_mem         hour    dayofweek  \
# count  4980.000000   4980.000000  4980.000000  4980.000000
# mean      0.085005    834.034962    11.236747     3.514458
# min       0.000000      2.580000     8.000000     3.000000
# 25%       0.013000    131.730000     8.000000     3.000000
# 50%       0.026000    197.850000    11.000000     4.000000
# 75%       0.083500    432.862500    13.000000     4.000000
# max       1.007400  32766.530000    18.000000     4.000000
# std       0.177192   2514.638144     3.020113     0.499841
#
#        cpu_utilization_ratio  mem_utilization_ratio  cat_deployment  \
# count            4980.000000            4980.000000     4980.000000
# mean                0.066997               0.208685      153.558635
# min                 0.000000               0.000000        0.000000
# 25%                 0.000000               0.020000       94.000000
# 50%                 0.003300               0.110000      173.000000
# 75%                 0.037000               0.280000      222.000000
# max                 1.001000               1.190000      222.000000
# std                 0.180760               0.250318       73.994053
#
#        cat_namespace  cat_controllerName  cat_controllerKind
# count    4980.000000         4980.000000         4980.000000
# mean      153.558635          207.954418            2.450602
# min         0.000000            0.000000            0.000000
# 25%        94.000000          139.750000            1.000000
# 50%       173.000000          230.000000            3.000000
# 75%       222.000000          305.000000            3.000000
# max       222.000000          402.000000            5.000000
# std        73.994053          119.150225            1.096915

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Correlation heatmap
features = [
        'cpuRequest', 'cpuLimit', 'cpuUsage',
        'memRequest', 'memLimit', 'memUsage',
        'avg_cpu_5min', 'avg_mem_5min', 'max_cpu', 'max_mem',
        'hour', 'dayofweek', 'is_weekend',
        'cpu_utilization_ratio', 'mem_utilization_ratio',
        'cat_deployment', 'cat_namespace', 'cat_controllerName', 'cat_controllerKind'
    ]
plt.figure(figsize=(16, 10))
correlation = df[features].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap-On Processed Data')
plt.show()
